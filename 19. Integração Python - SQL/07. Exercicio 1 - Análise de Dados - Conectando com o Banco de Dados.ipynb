# %% [markdown]
# ## Exercício Desafio
#
# - Digamos que seu chefe pediu para você um relatório da análise dos salários da unidade de San Francisco da empresa. O objetivo dele é entender:
#
# 1. Qual foi a evolução do salário médio ao longo dos anos (TotalPay e TotalPayBenefits)
# 2. Quantos funcionários tivemos ao longo dos anos
# 3. Qual foi a evolução do total gasto com salário ao longo dos anos (TotalPayBenefits)
#
# - Base de Dados a ser usada: salarios.sqlite

# %% [markdown]
# ### Importação da Base de Dados

# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt

conexao = sqlite3.connect('salarios.sqlite')
tabela_salarios = pd.read_sql('SELECT * FROM Salaries', conexao)

conexao.close()

display(tabela_salarios)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC         77916
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# 148649                                       Custodian             0
# 148650                                    Not provided  Not Provided
# 148651                                    Not provided  Not Provided
# 148652                                    Not provided  Not Provided
# 148653                      Counselor, Log Cabin Ranch             0
#
#          OvertimePay      OtherPay      Benefits   TotalPay  TotalPayBenefits  \
# 0                  0     400184.25                567595.43         567595.43
# 1          245131.88     137811.38                538909.28         538909.28
# 2          106088.18       16452.6                335279.91         335279.91
# 3           56120.71      198306.9                332343.61         332343.61
# 4               9737     182234.59                326373.19         326373.19
# ...              ...           ...           ...        ...               ...
# 148649             0             0             0       0.00              0.00
# 148650  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148651  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148652  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148653             0       -618.13             0    -618.13           -618.13
#
#         Year Notes         Agency Status
# 0       2011        San Francisco
# 1       2011        San Francisco
# 2       2011        San Francisco
# 3       2011        San Francisco
# 4       2011        San Francisco
# ...      ...   ...            ...    ...
# 148649  2014        San Francisco     PT
# 148650  2014        San Francisco
# 148651  2014        San Francisco
# 148652  2014        San Francisco
# 148653  2014        San Francisco     PT
#
# [148654 rows x 13 columns]

# %% [markdown]
# ### Análise de Dados

# %%
# garantindo que estamos só com San Francisco
tabela_salarios = tabela_salarios.loc[tabela_salarios['Agency'] =='San Francisco', :]
display(tabela_salarios)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC         77916
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# 148649                                       Custodian             0
# 148650                                    Not provided  Not Provided
# 148651                                    Not provided  Not Provided
# 148652                                    Not provided  Not Provided
# 148653                      Counselor, Log Cabin Ranch             0
#
#          OvertimePay      OtherPay      Benefits   TotalPay  TotalPayBenefits  \
# 0                  0     400184.25                567595.43         567595.43
# 1          245131.88     137811.38                538909.28         538909.28
# 2          106088.18       16452.6                335279.91         335279.91
# 3           56120.71      198306.9                332343.61         332343.61
# 4               9737     182234.59                326373.19         326373.19
# ...              ...           ...           ...        ...               ...
# 148649             0             0             0       0.00              0.00
# 148650  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148651  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148652  Not Provided  Not Provided  Not Provided       0.00              0.00
# 148653             0       -618.13             0    -618.13           -618.13
#
#         Year Notes         Agency Status
# 0       2011        San Francisco
# 1       2011        San Francisco
# 2       2011        San Francisco
# 3       2011        San Francisco
# 4       2011        San Francisco
# ...      ...   ...            ...    ...
# 148649  2014        San Francisco     PT
# 148650  2014        San Francisco
# 148651  2014        San Francisco
# 148652  2014        San Francisco
# 148653  2014        San Francisco     PT
#
# [148654 rows x 13 columns]

# %% [markdown]
# ##### 1. Qual foi a evolução do salário médio ao longo dos anos

# %%
salario_medio = tabela_salarios.groupby('Year').mean()
display(salirio_medio[['TotalPay','TotalPayBenefits']])
# Out:
# C:\Users\4960023091\AppData\Local\Temp\ipykernel_13140\2689370080.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   salario_medio = tabela_salarios.groupby('Year').mean()
#           TotalPay  TotalPayBenefits
# Year
# 2011  71744.103871      71744.103871
# 2012  74113.262265     100553.229232
# 2013  77611.443142     101440.519714
# 2014  75463.918140     100250.918884

# %% [markdown]
# ##### 2. Quantos funcionários tivemos ao longo dos anos

# %%
qtde = tabela_salarios.groupby('Year').count()
qtde = qtde[['Id']]
qtde = qtde.rename(columns={'Id':'Qtde_Funcionarios'})
display(qtde)
# Out:
#       Qtde_Funcionarios
# Year
# 2011              36159
# 2012              36766
# 2013              37606
# 2014              38123

# %% [markdown]
# ##### 3. Qual foi a evolução do total gasto com salário ao longo dos anos

# %%
def formatar(valor):
    return 'R${:,.2f}'.format(valor)

total_gastos = tabela_salarios.groupby('Year').sum()
total_gastos = total_gastos[['TotalPay','TotalPayBenefits']]
total_gastos['TotalPay'] = total_gastos['TotalPay'].apply(formatar)
total_gastos['TotalPayBenefits'] = total_gastos['TotalPayBenefits'].apply(formatar)
display(total_gastos)
# Out:
# C:\Users\4960023091\AppData\Local\Temp\ipykernel_13140\2836363897.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_gastos = tabela_salarios.groupby('Year').sum()
#                 TotalPay    TotalPayBenefits
# Year
# 2011  R$2,594,195,051.88  R$2,594,195,051.88
# 2012  R$2,724,848,200.44  R$3,696,940,025.96
# 2013  R$2,918,655,930.80  R$3,814,772,184.37
# 2014  R$2,876,910,951.26  R$3,821,865,780.60
